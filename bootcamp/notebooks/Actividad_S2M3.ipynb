# %%
import pandas as pd

# Crear el DataFrame con los datos
data = {
    "Jugador": ["Lionel Messi", "Cristiano Ronaldo", "Kevin De Bruyne", "Kylian Mbappé", "Luka Modric"],
    "Posición": ["Delantero", "Delantero", "Mediocampista", "Delantero", "Mediocampista"],
    "Edad": [35, 38, 31, 24, 37],
    "Goles": [20, 18, 8, 25, 3],
    "Asistencias": [10, 5, 15, 12, 8]
}

df = pd.DataFrame(data)
df
# Out:
#              Jugador       Posición  Edad  Goles  Asistencias
# 0       Lionel Messi      Delantero    35     20           10
# 1  Cristiano Ronaldo      Delantero    38     18            5
# 2    Kevin De Bruyne  Mediocampista    31      8           15
# 3      Kylian Mbappé      Delantero    24     25           12
# 4        Luka Modric  Mediocampista    37      3            8

# %%
df['Jugador']
# Out:
# 0         Lionel Messi
# 1    Cristiano Ronaldo
# 2      Kevin De Bruyne
# 3        Kylian Mbappé
# 4          Luka Modric
# Name: Jugador, dtype: object

# %%
df[df['Goles']>10][['Jugador','Goles']]
# Out:
#              Jugador  Goles
# 0       Lionel Messi     20
# 1  Cristiano Ronaldo     18
# 3      Kylian Mbappé     25

# %%
df['Puntos'] = 4*df['Goles'] + 2*df['Asistencias']
df
# Out:
#              Jugador       Posición  Edad  Goles  Asistencias  Puntos
# 0       Lionel Messi      Delantero    35     20           10     100
# 1  Cristiano Ronaldo      Delantero    38     18            5      82
# 2    Kevin De Bruyne  Mediocampista    31      8           15      62
# 3      Kylian Mbappé      Delantero    24     25           12     124
# 4        Luka Modric  Mediocampista    37      3            8      28

# %%
print(f"El promedio de goles es de {df['Goles'].mean()}")
# Out:
# El promedio de goles es de 14.8

# %%
print(f"Elminimo de asistencias es de {df['Asistencias'].min()} y el maximo son {df['Asistencias'].max()}")
# Out:
# Elminimo de asistencias es de 5 y el maximo son 15

# %%
df['Posición'].value_counts()
# Out:
# Posición
# Delantero        3
# Mediocampista    2
# Name: count, dtype: int64

# %%
df_sorted = df.sort_values(by='Goles', ascending=False)
df_sorted
# Out:
#              Jugador       Posición  Edad  Goles  Asistencias  Puntos
# 3      Kylian Mbappé      Delantero    24     25           12     124
# 0       Lionel Messi      Delantero    35     20           10     100
# 1  Cristiano Ronaldo      Delantero    38     18            5      82
# 2    Kevin De Bruyne  Mediocampista    31      8           15      62
# 4        Luka Modric  Mediocampista    37      3            8      28

# %%
df.describe()
# Out:
#             Edad      Goles  Asistencias      Puntos
# count   5.000000   5.000000     5.000000    5.000000
# mean   33.000000  14.800000    10.000000   79.200000
# std     5.700877   9.038805     3.807887   36.622398
# min    24.000000   3.000000     5.000000   28.000000
# 25%    31.000000   8.000000     8.000000   62.000000
# 50%    35.000000  18.000000    10.000000   82.000000
# 75%    37.000000  20.000000    12.000000  100.000000
# max    38.000000  25.000000    15.000000  124.000000

# %%
print(df['Posición'].value_counts())
# Out:
# Posición
# Delantero        3
# Mediocampista    2
# Name: count, dtype: int64
