# %%
precio_producto = float(input('Ingrese el precio del producto: '))
cantidad_producto = int(input('Ingrese la cantidad del producto: '))
descuento = float(input('Ingrese el descuento del producto: '))
# Out:
# Ingrese el precio del producto: 1200
# Ingrese la cantidad del producto: 3
# Ingrese el descuento del producto: 10

# %%
total_sin_descuento = precio_producto * cantidad_producto
print('Total sin descuento $',total_sin_descuento)
# Out:
# Total sin descuento $ 3600.0

# %%
monto_descuento = total_sin_descuento * (descuento / 100)
print('Monto de descuento $',monto_descuento)
# Out:
# Monto de descuento $ 360.0

# %%
total_con_descuento = total_sin_descuento - monto_descuento
print('Total con descuento $',total_con_descuento)
# Out:
# Total con descuento $ 3240.0
