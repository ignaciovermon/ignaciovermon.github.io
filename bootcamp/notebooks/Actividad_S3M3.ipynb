# %%
import pandas as pd

df = pd.read_csv('ventas.csv')
df.head(5)
# Out:
#    ID_Venta   Producto  Cantidad  Precio  Total
# 0       101     Laptop         1     800    800
# 1       102    Teclado         2      30     60
# 2       103      Mouse         3      15     45
# 3       104    Monitor         1     200    200
# 4       105  Impresora         1     150    150

# %%
df[['Producto','Precio']]
# Out:
#     Producto  Precio
# 0     Laptop     800
# 1    Teclado      30
# 2      Mouse      15
# 3    Monitor     200
# 4  Impresora     150
# 5   Cargador      25

# %%
df_filtrado = df[df['Precio'] > 50]
df_filtrado.to_csv('ventas_filtrado.csv')
df_filtrado
# Out:
#    ID_Venta   Producto  Cantidad  Precio  Total
# 0       101     Laptop         1     800    800
# 3       104    Monitor         1     200    200
# 4       105  Impresora         1     150    150
